# %% [markdown]
# <a href="https://colab.research.google.com/github/joncalle/ML2/blob/main/Chrun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
chr = pd.read_csv("https://raw.githubusercontent.com/joncalle/ML2/main/ChurnData.csv")
print(chr.shape) # print rows, columns
chr.head(10).T     # dump first 2 rows
# Out:
# (5630, 20)
#                                               0       1           2  \
# CustomerID                                50001   50002       50003
# Churn                                         1       1           1
# Tenure                                      4.0     NaN         NaN
# PreferredLoginDevice               Mobile Phone   Phone       Phone
# CityTier                                      3       1           1
# WarehouseToHome                             6.0     8.0        30.0
# PreferredPaymentMode                 Debit Card     UPI  Debit Card
# Gender                                   Female    Male        Male
# HourSpendOnApp                              3.0     3.0         2.0
# NumberOfDeviceRegistered                      3       4           4
# PreferedOrderCat             Laptop & Accessory  Mobile      Mobile
# SatisfactionScore                             2       3           3
# MaritalStatus                            Single  Single      Single
# ...

# %%
#verify there are no missing values
chr.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
chr = chr.fillna(0)
chr.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
for col in chr:
  print(chr[col].unique())
# Out:
# [50001 50002 50003 ... 55628 55629 55630]
# [1 0]
# [ 4.  0. 13. 11.  9. 19. 20. 14.  8. 18.  5.  2. 30.  1. 23.  3. 29.  6.
#  26. 28.  7. 24. 25. 10. 15. 22. 27. 16. 12. 21. 17. 50. 60. 31. 51. 61.]
# ['Mobile Phone' 'Phone' 'Computer']
# [3 1 2]
# [  6.   8.  30.  15.  12.  22.  11.   9.  31.  18.  13.  20.  29.  28.
#   26.  14.   0.  10.  27.  17.  23.  33.  19.  35.  24.  16.  25.  32.
#   34.   5.  21. 126.   7.  36. 127.]
# ['Debit Card' 'UPI' 'CC' 'Cash on Delivery' 'E wallet' 'COD' 'Credit Card']
# ['Female' 'Male']
# [3. 2. 0. 1. 4. 5.]
# [3 4 5 2 1 6]
# ['Laptop & Accessory' 'Mobile' 'Mobile Phone' 'Others' 'Fashion' 'Grocery']
# [2 3 5 4 1]
# ['Single' 'Divorced' 'Married']
# [ 9  7  6  8  3  2  4 10  1  5 19 21 11 20 22]
# [1 0]
# [11. 15. 14. 23. 22. 16. 12.  0. 13. 17. 18. 24. 19. 20. 21. 25. 26.]
# [ 1.  0.  4.  2.  9.  6. 11.  7. 12. 10.  5.  3. 13. 15.  8. 14. 16.]
# [ 1.  6.  2. 15.  4.  7.  3.  9.  0. 11.  5. 12. 10.  8. 13. 14. 16.]
# ...
